# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
il_mc_40g = pd.read_csv('../simulation_data/ILmc_40G.csv')

# %%
no_bins = 51

jb = stats.jarque_bera(il_mc_40g[' IL (1 25C)'])
sk = stats.skew(il_mc_40g[' IL (1 25C)'])
kt = stats.kurtosis(il_mc_40g[' IL (1 25C)'])
median = np.median(il_mc_40g[' IL (1 25C)'])
std = np.std(il_mc_40g[' IL (1 25C)'])
plt.figure(figsize=(12, 6))
plt.subplot(221)
plt.hist(il_mc_40g[' IL (1 25C)'], bins=no_bins, density=True, label=r'Jarque-Bera = %.2f'%(jb[0])+ f'\n'+r'Skew = %.2f'%(sk) + f'\n' + r'Kurtosis = %.2f'%(kt) + f'\n' + r'Median = %.2f dB'%(median) + f'\n' + r'1-$\sigma$ = %.2f dB' %(std))
plt.legend()
plt.grid(True)
plt.title('Ch-1')
plt.xlim([-1, 0])
plt.xlabel('IL [dB]')

jb = stats.jarque_bera(il_mc_40g[' IL (2 25C)'])
sk = stats.skew(il_mc_40g[' IL (2 25C)'])
kt = stats.kurtosis(il_mc_40g[' IL (2 25C)'])
median = np.median(il_mc_40g[' IL (2 25C)'])
std = np.std(il_mc_40g[' IL (2 25C)'])

plt.subplot(222)
plt.hist(il_mc_40g[' IL (2 25C)'], bins=no_bins, density=True, label=r'Jarque-Bera = %.2f'%(jb[0])+ f'\n'+r'Skew = %.2f'%(sk) + f'\n' + r'Kurtosis = %.2f'%(kt) + f'\n' + r'Median = %.2f dB'%(median) + f'\n' + r'1-$\sigma$ = %.2f dB' %(std))
plt.legend()
plt.grid(True)
plt.title('Ch-4')
plt.xlim([-1, 0])
plt.xlabel('IL [dB]')

jb = stats.jarque_bera(il_mc_40g[' IL (3 25C)'])
sk = stats.skew(il_mc_40g[' IL (3 25C)'])
kt = stats.kurtosis(il_mc_40g[' IL (3 25C)'])
median = np.median(il_mc_40g[' IL (3 25C)'])
std = np.std(il_mc_40g[' IL (3 25C)'])

plt.subplot(223)
plt.hist(il_mc_40g[' IL (3 25C)'], bins=no_bins, density=True, label=r'Jarque-Bera = %.2f'%(jb[0])+ f'\n'+r'Skew = %.2f'%(sk) + f'\n' + r'Kurtosis = %.2f'%(kt) + f'\n' + r'Median = %.2f dB'%(median) + f'\n' + r'1-$\sigma$ = %.2f dB' %(std))
plt.legend()
plt.grid(True)
plt.title('Ch-5')
plt.xlim([-1, 0])
plt.xlabel('IL [dB]')

jb = stats.jarque_bera(il_mc_40g[' IL (4 25C)'])
sk = stats.skew(il_mc_40g[' IL (4 25C)'])
kt = stats.kurtosis(il_mc_40g[' IL (4 25C)'])
median = np.median(il_mc_40g[' IL (4 25C)'])
std = np.std(il_mc_40g[' IL (4 25C)'])

plt.subplot(224)
plt.hist(il_mc_40g[' IL (4 25C)'], bins=no_bins, density=True, label=r'Jarque-Bera = %.2f'%(jb[0])+ f'\n'+r'Skew = %.2f'%(sk) + f'\n' + r'Kurtosis = %.2f'%(kt) + f'\n' + r'Median = %.2f dB'%(median) + f'\n' + r'1-$\sigma$ = %.2f dB' %(std))
plt.legend()
plt.grid(True)
plt.title('Ch-8')
plt.xlim([-1, 0])
plt.xlabel('IL [dB]')
plt.tight_layout()

# %%
il_mc_40g.describe()
# Out:
#           f (1 25C)     f (2 25C)     f (3 25C)     f (4 25C)   IL (1 25C)  \
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2000.000000
# mean   1.308285e-06  1.310573e-06  1.301470e-06  1.317484e-06    -0.483282
# std    7.606733e-11  7.639930e-11  7.527397e-11  7.720568e-11     0.083481
# min    1.308017e-06  1.310299e-06  1.301221e-06  1.317208e-06    -0.886076
# 25%    1.308234e-06  1.310521e-06  1.301419e-06  1.317432e-06    -0.528696
# 50%    1.308285e-06  1.310573e-06  1.301470e-06  1.317484e-06    -0.471401
# 75%    1.308336e-06  1.310624e-06  1.301520e-06  1.317536e-06    -0.423234
# max    1.308544e-06  1.310830e-06  1.301757e-06  1.317744e-06    -0.280922
#
#         IL (2 25C)   IL (3 25C)   IL (4 25C)
# count  2000.000000  2000.000000  2000.000000  0.0
# mean     -0.479327    -0.506629    -0.469585  NaN
# std       0.086593     0.074481     0.096376  NaN
# min      -0.861218    -0.968382    -0.948023  NaN
# ...
