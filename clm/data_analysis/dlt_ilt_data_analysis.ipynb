# %%
import numpy as np 
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dlt_data  = pd.read_csv('dlt_summary_untested_dies.csv')
dlt_data.describe()
# Out:
#            Die_ID  Laser_channel     Temp(C)  Dλ/DT (nm/C)_150mA  \
# count  466.000000     466.000000  466.000000          466.000000
# mean    14.931330       8.388412   42.849785            0.087434
# std      5.252711       4.612908    5.713498            0.025856
# min      7.000000       1.000000   36.000000           -0.043786
# 25%     11.000000       4.000000   36.000000            0.087929
# 50%     15.000000       8.000000   43.000000            0.088571
# 75%     18.000000      12.000000   50.000000            0.089500
# max     26.000000      16.000000   50.000000            0.246071
#
#        Dλ/DIV (nm/mA)  Dλ/DIV (GHz/mA)  Dλ/DT (GHz/C)_150mA  Top(C)_150mA  \
# count      466.000000       466.000000           466.000000    466.000000
# mean         0.002971        -0.519338           -15.288146     47.864076
# std          0.003317         0.580669             4.544382      2.467629
# min         -0.012230        -6.772521           -43.257671     36.000000
# ...

# %%
dlt_data.columns
# Out:
# Index(['Die_ID', 'Laser_channel', 'Temp(C)', 'Dλ/DT (nm/C)_150mA',
#        'Dλ/DIV (nm/mA)', 'Dλ/DIV (GHz/mA)', 'Dλ/DT (GHz/C)_150mA',
#        'Top(C)_150mA', 'Die_Top', 'Threshold Current (A)',
#        'Slope Efficiency (W/A)', 'Series Resistance (Ohms)',
#        'Turn-On Voltage (V)', 'Power_125', 'Power_150', 'Power_165',
#        'Voltage_125', 'Voltage_150', 'Voltage_165', 'Rd_125', 'Rd_150',
#        'Rd_165', 'WPE_125', 'WPE_150', 'WPE_165'],
#       dtype='object')

# %%
dlt_data['Die_ID'] = dlt_data['Die_ID'].astype(str)
dlt_data['Laser_channel'] = dlt_data['Laser_channel'].astype(str)
dlt_data['Temp(C)'] = dlt_data['Temp(C)'].astype(str)

# %%
px.scatter(dlt_data, x='Laser_channel', y='Dλ/DT (GHz/C)_150mA', color='Die_ID', title='DLT Summary')

# %%
px.scatter(dlt_data, x='Laser_channel', y='Dλ/DIV (GHz/mA)', color='Die_ID', title='DLT Summary')

# %%
px.scatter(dlt_data, x='Laser_channel', y='Power_150', color='Temp(C)', title='DLT Summary')

# %%
px.scatter(dlt_data, x='Laser_channel', y='Top(C)_150mA', color='Die_ID', title='DLT Summary')
