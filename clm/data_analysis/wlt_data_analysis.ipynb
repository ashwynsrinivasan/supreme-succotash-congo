# %%
import numpy as np 
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## ES0 tested dies - WLT

# %%
wlt_data_20250225 = pd.read_csv('wlt_data_summary_20250225.csv')
wlt_data_20250225["Date"]  = "2025-02-25"
wlt_data_20250225["TBI"]  = False
wlt_data_20250228 = pd.read_csv('wlt_data_summary_20250228.csv')
wlt_data_20250228["Date"]  = "2025-02-28"
wlt_data_20250228["TBI"]  = False
wlt_data_20250403 = pd.read_csv('wlt_data_summary_20250403.csv')
wlt_data_20250403["Date"]  = "2025-04-03"
wlt_data_20250403["TBI"]  = True

wlt_data_20250507_1= pd.read_csv('wlt_data_summary_20250507_1.csv')
wlt_data_20250507_1["Date"]  = "2025-05-07"
wlt_data_20250507_1["TBI"]  = False

wlt_data_20250507_2 = pd.read_csv('wlt_data_summary_20250507_2.csv')
wlt_data_20250507_2["Date"]  = "2025-05-07"
wlt_data_20250507_2["TBI"]  = False

wlt_data_20250508 = pd.read_csv('wlt_data_summary_20250508.csv')
wlt_data_20250508["Date"]  = "2025-05-08"
wlt_data_20250508["TBI"]  = True

wlt_data  = pd.concat([wlt_data_20250225, wlt_data_20250228, wlt_data_20250403, wlt_data_20250507_1,wlt_data_20250507_2, wlt_data_20250508], ignore_index=True)

# %%
wlt_data['Diode Bias (V)'] = 10**(wlt_data['Minimum Facet Power (dBm)']/10) / wlt_data['Total WPE Estimate (%)'] / 1000 * 100 / 145e-3

# %%
wlt_data.describe()
# Out:
#                DIE          Bin  Minimum Facet Power (dBm)  \
# count  4442.000000  2425.000000                4442.000000
# mean    508.738856     2.741856                  13.459577
# std     405.071315     0.668233                   0.998563
# min       1.000000     1.000000                  10.008972
# 25%     186.000000     3.000000                  13.019266
# 50%     372.000000     3.000000                  13.636236
# 75%     803.750000     3.000000                  14.224622
# max    1543.000000     3.000000                  14.945189
#
#        Backside Temperature (C)  Worst SMSR (dB)  Worst RIN (dBc/Hz)  \
# count               4442.000000      4442.000000         4442.000000
# mean                  43.483652        50.474593         -158.331635
# std                    3.832274         1.044278            0.900555
# min                   31.732170        40.578923         -159.295641
# 25%                   40.812551        50.002127         -158.749066
# ...

# %%
fig1 = px.histogram(wlt_data, x='Minimum Facet Power (dBm)', color="Date", nbins=100, title='WLT Distribution',width=800, height=400)
fig1.update_layout(xaxis_range=[8,16], title=dict(text=f"Median={wlt_data['Minimum Facet Power (dBm)'].median():0.2f}, Std={wlt_data['Minimum Facet Power (dBm)'].std():0.2f}, min spec = 14 dBm", font=dict(size=25)))
fig1.write_image("images/histogram_min_facet_power.png")
fig1.show()

fig2 = px.histogram(wlt_data, x='Worst Relative Frequency Error (GHz)', color="Date", nbins=100, title='WLT Distribution',width=800, height=400)
fig2.update_layout(xaxis_range=[0, 50], title=dict(text=f"Median={wlt_data['Worst Relative Frequency Error (GHz)'].median():0.2f}, Std={wlt_data['Worst Relative Frequency Error (GHz)'].std():0.2f}, max spec = 36 GHz", font=dict(size=25)))
fig2.write_image("images/histogram_worst_relative_frequency_error.png")
fig2.show()

fig3 = px.histogram(wlt_data, x='Total WPE Estimate (%)', color="Date", nbins=100, title='WLT Distribution',width=800, height=400)
fig3.update_layout(xaxis_range=[5, 20], title=dict(text=f"Median={wlt_data['Total WPE Estimate (%)'].median():0.2f}, Std={wlt_data['Total WPE Estimate (%)'].std():0.2f}, typical spec = 14%", font=dict(size=25)))
fig3.write_image("images/histogram_total_wpe_estimate.png")
fig3.show()

fig4 = px.histogram(wlt_data, x='Backside Temperature (C)', color="Date", nbins=100, title='WLT Distribution',width=800, height=400)
fig4.update_layout(xaxis_range=[30,60], title=dict(text=f"Median={wlt_data['Backside Temperature (C)'].median():0.1f}, Std={wlt_data['Backside Temperature (C)'].std():0.1f}, typical spec = 35 to 50C", font=dict(size=25)))
fig4.write_image("images/histogram_backside_temperature.png")
fig4.show()

fig5 = px.histogram(wlt_data, x='Worst RIN (dBc/Hz)', color="Date", nbins=100, title='WLT Distribution',width=800, height=400)
fig5.update_layout(xaxis_range=[-160, -140], title=dict(text=f"Median={wlt_data['Worst RIN (dBc/Hz)'].median():0.1f}, Std={wlt_data['Worst RIN (dBc/Hz)'].std():0.1f}, max spec = -145 dBc/Hz", font=dict(size=25)))
fig5.write_image("images/histogram_worst_rin.png")
fig5.show()

fig6 = px.histogram(wlt_data, x='Worst SMSR (dB)', color="Date", nbins=100, title='WLT Distribution',width=800, height=400)
fig6.update_layout(xaxis_range=[40, 60], title=dict(text=f"Median={wlt_data['Worst SMSR (dB)'].median():0.1f}, Std={wlt_data['Worst SMSR (dB)'].std():0.1f}, min spec = 40 dB", font=dict(size=25)))
fig6.write_image("images/histogram_worst_smsr.png")
fig6.show()

fig7 = px.histogram(wlt_data, x='Diode Bias (V)', color="Date", nbins=100, title='WLT Distribution',width=800, height=400)
fig7.update_layout(xaxis_range=[0, 2], title=dict(text=f"Median={wlt_data['Diode Bias (V)'].median():0.1f}, Std={wlt_data['Diode Bias (V)'].std():0.1f}", font=dict(size=25)))
fig7.write_image("images/histogram_max_bias.png")
fig7.show()

# %%
fig1 = px.scatter(wlt_data, x='Minimum Facet Power (dBm)', y='Total WPE Estimate (%)',color="Date", width=800, height=400)
fig1.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Minimum Facet Power (dBm)'].corr(wlt_data['Total WPE Estimate (%)']):0.1f}", font=dict(size=25)))
fig1.write_image("images/scatter_min_facet_power_vs_total_wpe_estimate.png")
fig1.show()

fig2 = px.scatter(wlt_data, x='Minimum Facet Power (dBm)', y='Diode Bias (V)',color="Date", width=800, height=400)
fig2.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Minimum Facet Power (dBm)'].corr(wlt_data['Diode Bias (V)']):0.1f}", font=dict(size=25)))
fig2.write_image("images/scatter_min_facet_power_vs_bias_voltage.png")
fig2.show()

fig3 = px.scatter(wlt_data, x='Minimum Facet Power (dBm)', y='Worst Relative Frequency Error (GHz)',color="Date", width=800, height=400)
fig3.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Minimum Facet Power (dBm)'].corr(wlt_data['Worst Relative Frequency Error (GHz)']):0.1f}", font=dict(size=25)))
fig3.write_image("images/scatter_min_facet_power_vs_worst_relative_frequency_error.png")
fig3.show()

fig4 = px.scatter(wlt_data, x='Worst RIN (dBc/Hz)', y='Worst Relative Frequency Error (GHz)',color="Date", width=800, height=400)
fig4.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Worst RIN (dBc/Hz)'].corr(wlt_data['Worst Relative Frequency Error (GHz)']):0.1f}", font=dict(size=25)))
fig4.write_image("images/scatter_worst_rin_vs_worst_relative_frequency_error.png")
fig4.show()

fig5 = px.scatter(wlt_data, x='Worst RIN (dBc/Hz)', y='Worst SMSR (dB)',color="Date", width=800, height=400)
fig5.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Worst RIN (dBc/Hz)'].corr(wlt_data['Worst SMSR (dB)']):0.1f}", font=dict(size=25)))
fig5.write_image("images/scatter_worst_rin_vs_worst_smsr.png")
fig5.show()

# %%
wlt_data.columns
# Out:
# Index(['DIE', 'Bin', 'Minimum Facet Power (dBm)', 'Backside Temperature (C)',
#        'Worst SMSR (dB)', 'Worst RIN (dBc/Hz)',
#        'Worst Relative Frequency Error (GHz)', 'Total WPE Estimate (%)',
#        'Date', 'TBI', 'BIN', 'Diode Bias (V)'],
#       dtype='object')

# %%
## Product Samples
power_trim_product = 13.5
WPE_trim_product = 11
freq_trim_product = 25
# smsr_trim_product = 50
# rin_trim_product = -155

## Test Samples
power_trim_testing = 12.5
WPE_trim_testing = 10

## Rests are Mechanical Samples
wlt_data['Phase1'] = "Mechanical Sample"
wlt_data.loc[(wlt_data['Minimum Facet Power (dBm)'] >= power_trim_testing) & (wlt_data['Total WPE Estimate (%)'] >= WPE_trim_testing), 'Phase1'] = "Test Sample"
wlt_data.loc[(wlt_data['Minimum Facet Power (dBm)'] > power_trim_product) & (wlt_data['Worst Relative Frequency Error (GHz)'] < freq_trim_product) & (wlt_data['Total WPE Estimate (%)'] > WPE_trim_product), 'Phase1'] = "Product Sample"

# %%
wlt_data['Phase1'].unique()
# Out:
# array(['Product Sample', 'Test Sample', 'Mechanical Sample'], dtype=object)

# %%
fig1 = px.scatter(wlt_data, x='Minimum Facet Power (dBm)', y='Total WPE Estimate (%)',color="Phase1", width=800, height=400)
fig1.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Minimum Facet Power (dBm)'].corr(wlt_data['Total WPE Estimate (%)']):0.1f}", font=dict(size=25)))
fig1.write_image("images/scatter_min_facet_power_vs_total_wpe_estimate_phase1_with_bins.png")
fig1.show()

fig2 = px.scatter(wlt_data, x='Minimum Facet Power (dBm)', y='Diode Bias (V)',color="Phase1", width=800, height=400)
fig2.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Minimum Facet Power (dBm)'].corr(wlt_data['Diode Bias (V)']):0.1f}", font=dict(size=25)))
fig2.write_image("images/scatter_min_facet_power_vs_bias_voltage_phase1_with_bins.png")
fig2.show()

fig3 = px.scatter(wlt_data, x='Minimum Facet Power (dBm)', y='Worst Relative Frequency Error (GHz)',color="Phase1", width=800, height=400)
fig3.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Minimum Facet Power (dBm)'].corr(wlt_data['Worst Relative Frequency Error (GHz)']):0.1f}", font=dict(size=25)))
fig3.write_image("images/scatter_min_facet_power_vs_worst_relative_frequency_error_phase1_with_bins.png")
fig3.show()

fig4 = px.scatter(wlt_data, x='Worst RIN (dBc/Hz)', y='Worst Relative Frequency Error (GHz)',color="Phase1", width=800, height=400)
fig4.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Worst RIN (dBc/Hz)'].corr(wlt_data['Worst Relative Frequency Error (GHz)']):0.1f}", font=dict(size=25)))
fig4.write_image("images/scatter_worst_rin_vs_worst_relative_frequency_error_phase1_with_bins.png")
fig4.show()

fig5 = px.scatter(wlt_data, x='Worst RIN (dBc/Hz)', y='Worst SMSR (dB)',color="Phase1", width=800, height=400)
fig5.update_layout(title=dict(text=f"Cross-correlation={wlt_data['Worst RIN (dBc/Hz)'].corr(wlt_data['Worst SMSR (dB)']):0.1f}", font=dict(size=25)))
fig5.write_image("images/scatter_worst_rin_vs_worst_smsr_phase1_with_bins.png")
fig5.show()

# %%
fig1 = px.histogram(wlt_data, x='Phase1', color='Date', width=800, height=400)
fig1.write_image("images/histogram_phase1_with_bins.png")
fig1.show()

# %%
product_samples = wlt_data[wlt_data['Phase1'] == "Product Sample"]
product_samples.describe()
# Out:
#               DIE         Bin  Minimum Facet Power (dBm)  \
# count  2356.00000  901.000000                2356.000000
# mean    563.08489    2.339623                  14.147236
# std     423.12074    0.936943                   0.364440
# min       1.00000    1.000000                  13.500657
# 25%     205.75000    1.000000                  13.839302
# 50%     434.00000    3.000000                  14.165739
# 75%     871.25000    3.000000                  14.445216
# max    1543.00000    3.000000                  14.945189
#
#        Backside Temperature (C)  Worst SMSR (dB)  Worst RIN (dBc/Hz)  \
# count               2356.000000      2356.000000         2356.000000
# mean                  43.642056        50.528013         -158.517421
# std                    3.783466         0.930377            0.456465
# min                   32.121724        41.592443         -159.295641
# 25%                   40.996613        50.108727         -158.773560
# ...

# %%
fig1 = px.histogram(product_samples, x='Minimum Facet Power (dBm)', color="Date", nbins=51, title='Product Samples',width=800, height=400)
fig1.update_layout(xaxis_range=[13,16], title=dict(text=f"Median={product_samples['Minimum Facet Power (dBm)'].median():0.2f}, Std={product_samples['Minimum Facet Power (dBm)'].std():0.2f}, min spec = 14 dBm", font=dict(size=25)))
fig1.write_image("images/histogram_min_facet_power_product_samples.png")
fig1.show()

fig2 = px.histogram(product_samples, x='Worst Relative Frequency Error (GHz)', color="Date", nbins=51, title='Product Samples',width=800, height=400)
fig2.update_layout(xaxis_range=[0, 50], title=dict(text=f"Median={product_samples['Worst Relative Frequency Error (GHz)'].median():0.2f}, Std={product_samples['Worst Relative Frequency Error (GHz)'].std():0.2f}, max spec = 36 GHz", font=dict(size=25)))
fig2.write_image("images/histogram_worst_relative_frequency_error_product_samples.png")
fig2.show()

fig3 = px.histogram(product_samples, x='Total WPE Estimate (%)', color="Date", nbins=51, title='Product Samples',width=800, height=400)
fig3.update_layout(xaxis_range=[10, 20], title=dict(text=f"Median={product_samples['Total WPE Estimate (%)'].median():0.2f}, Std={product_samples['Total WPE Estimate (%)'].std():0.2f}, typical spec = 14%", font=dict(size=25)))
fig3.write_image("images/histogram_total_wpe_estimate_product_samples.png")
fig3.show()

fig4 = px.histogram(product_samples, x='Backside Temperature (C)', color="Date", nbins=51, title='Product Samples',width=800, height=400)
fig4.update_layout(xaxis_range=[30,60], title=dict(text=f"Median={product_samples['Backside Temperature (C)'].median():0.1f}, Std={product_samples['Backside Temperature (C)'].std():0.1f}, typical spec = 35 to 50C", font=dict(size=25)))
fig4.write_image("images/histogram_backside_temperature_product_samples.png")
fig4.show()

fig5 = px.histogram(product_samples, x='Worst RIN (dBc/Hz)', color="Date", nbins=51, title='Product Samples',width=800, height=400)
fig5.update_layout(xaxis_range=[-160, -140], title=dict(text=f"Median={product_samples['Worst RIN (dBc/Hz)'].median():0.1f}, Std={product_samples['Worst RIN (dBc/Hz)'].std():0.1f}, max spec = -145 dBc/Hz", font=dict(size=25)))
fig5.write_image("images/histogram_worst_rin_product_samples.png")
fig5.show()

fig6 = px.histogram(product_samples, x='Worst SMSR (dB)', color="Date", nbins=51, title='Product Samples',width=800, height=400)
fig6.update_layout(xaxis_range=[40, 60], title=dict(text=f"Median={product_samples['Worst SMSR (dB)'].median():0.1f}, Std={product_samples['Worst SMSR (dB)'].std():0.1f}, min spec = 40 dB", font=dict(size=25)))
fig6.write_image("images/histogram_worst_smsr_product_samples.png")
fig6.show()

fig7 = px.histogram(product_samples, x='Diode Bias (V)', color="Date", nbins=51, title='Product Samples',width=800, height=400)
fig7.update_layout(xaxis_range=[1, 1.6], title=dict(text=f"Median={product_samples['Diode Bias (V)'].median():0.1f}, Std={product_samples['Diode Bias (V)'].std():0.1f}", font=dict(size=25)))
fig7.write_image("images/histogram_max_bias_product_samples.png")
fig7.show()

# %% [markdown]
# ## Data analysis on WLT
