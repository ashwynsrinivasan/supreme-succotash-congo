# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import xarray as xr
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
plt.style.use("plot_style.mplstyle")

# %%
interleaver_2_stages = xr.open_dataset('interleaver_2_stage_dataset_20240109.nc')
interleaver_2_stages
# Out:
# <xarray.Dataset>
# Dimensions:              (idd_rand: 20001, wavelength: 4000, idd_fom: 8,
#                           channel_offset: 8, fom_params: 7, wg_params: 6,
#                           dc_params: 3, dc_sigma: 3, phase_params: 2,
#                           sim_mode: 1, dc_variability_mode: 1, route_wg: 1)
# Coordinates:
#   * idd_rand             (idd_rand) int32 0 1 2 3 4 ... 19997 19998 19999 20000
#   * wavelength           (wavelength) float64 1.295e-06 1.295e-06 ... 1.325e-06
#   * idd_fom              (idd_fom) object 'ch1' 'ch2' 'ch3' ... 'ch7' 'ch8'
#   * channel_offset       (channel_offset) float64 0.0 1e+10 ... 6e+10 7e+10
#   * fom_params           (fom_params) object '1dB_bandwidth' ... 'ripple_dc_i...
#   * wg_params            (wg_params) object 'wg_width' 'wg_height' ... 'ng'
#   * dc_params            (dc_params) object 'dc1' 'dc2' 'dc3'
#   * dc_sigma             (dc_sigma) float64 0.02 0.05 0.1
# ...

# %%
interleaver_2_stages['wavelength'].values
# Out:
# array([1.2950000e-06, 1.2950075e-06, 1.2950150e-06, ..., 1.3249850e-06,
#        1.3249925e-06, 1.3250000e-06])

# %%
interleaver_2_stages['wg'].sel()
# Out:
# array(['wg_width', 'wg_height', 'wg_sidewall_angle',
#        'wg_width_median_array', 'neff', 'ng'], dtype=object)

# %%
interleaver_2_stages['route_wg'].values
# Out:
# array([0.8])

# %%
256*64
# Out:
# 16384

# %%
256*64*8*(1-0.999)
# Out:
# 131.07200000000012
